# %%
# Importing Default Libraries
import cv2 as cv
import numpy as np
import sys

# Defining important paths
im_dir = r'E:/Semester 4/EN2550_FundamentalsOfImageProcessing/Fun-Time/Exercises/images/'
lib_dir="E:\Semester 4\EN2550_FundamentalsOfImageProcessing\Fun-Time\lib"

# Importing Custom Functions
sys.path.append(lib_dir)
from show_images import show_images
from point_operations import equlize_histogram_,image_brighten

# %%
def intensity_transformation(image,transformation):
    return cv.LUT(image,transformation)              # return transformation[image] <- Alternative

def equlize_histogram(image):
    return cv.equalizeHist(image)

# %%
# Showing Image Properties
f=cv.imread(im_dir+'spider.png')
assert f is not None

show_images([[f,'c',"Original Image"]])
print("Shape : ",f.shape)
print("Size : ",f.size)
print("Data type : ",f.dtype)
# Out:
# Shape :  (438, 780, 3)
# Size :  1024920
# Data type :  uint8

# %%
# Showing Image Properties
f=cv.imread(im_dir+'spider.png',cv.IMREAD_GRAYSCALE)
assert f is not None

show_images([[f,'g',"Original Image"],[equlize_histogram(f),'g',"Equalized Image 1"],[equlize_histogram_(f),'g',"Equalized Image 2"]])
